# %%
# 필요한 라이브러리 설치
# !pip install asteroid torch torchaudio soundfile tqdm matplotlib thop
# Out:
# Requirement already satisfied: asteroid in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: thop in /usr/local/lib/python3.10/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.10/dist-packages (from asteroid) (1.26.4)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from asteroid) (1.13.1)
# Requirement already satisfied: asteroid-filterbanks>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.4.0)
# Requirement already satisfied: huggingface-hub>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.26.3)
# Requirement already satisfied: PyYAML>=5.0 in /usr/local/lib/python3.10/dist-packages (from asteroid) (6.0.2)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from asteroid) (2.2.2)
# Requirement already satisfied: pytorch-lightning>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from asteroid) (2.4.0)
# Requirement already satisfied: torchmetrics<=0.11.4 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.11.4)
# Requirement already satisfied: pb-bss-eval>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.0.2)
# Requirement already satisfied: torch-stoi>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.2.3)
# Requirement already satisfied: torch-optimizer<0.2.0,>=0.0.1a12 in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.1.0)
# Requirement already satisfied: julius in /usr/local/lib/python3.10/dist-packages (from asteroid) (0.2.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.0.2->asteroid) (2.32.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->asteroid) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->asteroid) (2024.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.10/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (2.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.8.0)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.10/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.4.1)
# Requirement already satisfied: mir-eval in /usr/local/lib/python3.10/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.7)
# Requirement already satisfied: pesq in /usr/local/lib/python3.10/dist-packages (from pb-bss-eval>=0.0.2->asteroid) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->asteroid) (0.11.9)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from torch-optimizer<0.2.0,>=0.0.1a12->asteroid) (0.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (3.11.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=2.0.0->asteroid) (75.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from mir-eval->pb-bss-eval>=0.0.2->asteroid) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.0.2->asteroid) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->asteroid) (1.18.3)

# %%
# !pip install torchinfo ptflops
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: ptflops in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.10/dist-packages (from ptflops) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0->ptflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->ptflops) (3.0.2)

# %%
import os
import torch
import soundfile as sf
# 기존: from asteroid.models import DPTNet
from asteroid.models import DPRNNTasNet
# from asteroid.losses import SI_SNR
from ptflops import get_model_complexity_info

# %%
# SI-SNR 계산 함수 (직접 구현)
def calculate_si_snr(estimation, reference):
    """
    Args:
        estimation (torch.Tensor): 추정된 오디오 (B, T)
        reference (torch.Tensor): 참조 오디오 (B, T)

    Returns:
        si_snr (torch.Tensor): SI-SNR 값 (B,)
    """
    reference = reference - reference.mean(dim=-1, keepdim=True)
    estimation = estimation - estimation.mean(dim=-1, keepdim=True)
    # Inner product
    s_target = torch.sum(estimation * reference, dim=-1, keepdim=True) * reference / torch.sum(reference**2, dim=-1, keepdim=True)
    e_noise = estimation - s_target
    si_snr = 10 * torch.log10(torch.sum(s_target**2, dim=-1) / torch.sum(e_noise**2, dim=-1))
    return si_snr

# %%
# 데이터셋 로드 함수
def load_dataset(dataset_path):
    """
    Args:
        dataset_path (str): 데이터셋의 최상위 폴더 경로 (/test)

    Returns:
        file_list (list): 데이터 파일 리스트 [(mixed_path, [s1_path, s2_path]), ...]
    """
    mixed_path = os.path.join(dataset_path, "mixed_data")
    source_paths = [os.path.join(dataset_path, "s1"), os.path.join(dataset_path, "s2")]

    file_list = []
    for filename in os.listdir(mixed_path):
        if filename.endswith(".wav"):
            mixed_file = os.path.join(mixed_path, filename)
            sources = [os.path.join(source_path, filename) for source_path in source_paths]
            file_list.append((mixed_file, sources))
    return file_list

# %%
# 모델 초기화
def initialize_model():
    model = DPRNNTasNet(n_src=2)  # 2개의 소스 분리
    model.eval()
    return model

# %%
from asteroid.metrics import get_metricsdef calculate_sdr(estimation, reference):
    """
    SDR (Signal-to-Distortion Ratio) 계산
    Args:
        estimation (Tensor): 추정된 신호 (B, T)
        reference (Tensor): 참조 신호 (B, T)

    Returns:
        sdr (Tensor): SDR 값 (B,)
    """
    reference_energy = torch.sum(reference**2, dim=-1)
    projection = torch.sum(estimation * reference, dim=-1) * reference / reference_energy
    noise = estimation - projection
    sdr = 10 * torch.log10(torch.sum(projection**2, dim=-1) / torch.sum(noise**2, dim=-1))
    return sdr

def calculate_sdri(estimates, references, mixture):
    """
    SDRi (Signal-to-Distortion Ratio improvement) 계산
    Args:
        estimates (Tensor): 추정된 신호 (N, T)
        references (Tensor): 참조 신호 (N, T)
        mixture (Tensor): 혼합 신호 (1, T)

    Returns:
        sdri (float): SDRi 값
    """
    # SDR 계산
    sdr_mixture = calculate_sdr(mixture.repeat(references.size(0), 1), references).mean().item()
    sdr_estimates = calculate_sdr(estimates, references).mean().item()

    # SDRi 계산
    sdri = sdr_estimates - sdr_mixture
    return sdri

def calculate_metrics(estimates, references, mixture):
    """
    Args:
        estimates (Tensor): 추정된 소스 신호 (N, T)
        references (list of torch.Tensor): 참조 신호 리스트
        mixture (Tensor): 혼합 신호

    Returns:
        si_snri (float): SI-SNRi 값
        sdri (float): SDRi 값
    """
    # estimates 텐서 변환: (B, N, T) -> (N, T)
    estimates = estimates.squeeze(0)  # (N, T)
    print(f"Adjusted estimates shape: {estimates.shape}")

    # 모델 출력 길이에 참조 신호 길이 맞추기
    ref_len = estimates.size(1)
    references = [
        torch.tensor(ref[:ref_len], dtype=torch.float32) if len(ref) > ref_len
        else torch.nn.functional.pad(torch.tensor(ref, dtype=torch.float32), (0, ref_len - len(ref)))
        for ref in references
    ]
    references = torch.stack(references)  # (N, T)

    # 혼합 신호 길이 맞추기
    mixture = mixture[:, :ref_len]  # (1, T)

    # SI-SNRi 계산
    si_snr_mixture = calculate_si_snr(mixture.repeat(len(references), 1), references).mean().item()
    si_snr_estimates = calculate_si_snr(estimates, references).mean().item()
    si_snri = si_snr_estimates - si_snr_mixture

    # SDRi 계산
    sdri = calculate_sdri(estimates, references, mixture)

    return si_snri, sdri
# Out:
#   File "<ipython-input-34-17003b66c94e>", line 1
#     from asteroid.metrics import get_metricsdef calculate_sdr(estimation, reference):
#                                                 ^
# SyntaxError: invalid syntax

# %%
from asteroid.metrics import get_metrics
def calculate_metrics(estimates, references, mixture):
    """
    Args:
        estimates (Tensor): 추정된 소스 신호 (N, T)
        references (list of torch.Tensor): 정답 소스 신호 리스트
        mixture (torch.Tensor): 혼합 신호

    Returns:
        si_snri (float): SI-SNRi 값
        sdri (float): SDRi 값
    """
    # estimates 텐서 변환: (B, N, T) -> (N, T)
    estimates = estimates.squeeze(0)  # (N, T)
    print(f"Adjusted estimates shape: {estimates.shape}")

    # 모델 출력 길이에 참조 신호 길이 맞추기
    ref_len = estimates.size(1)
    references = [
        torch.tensor(ref[:ref_len], dtype=torch.float32) if len(ref) > ref_len
        else torch.nn.functional.pad(torch.tensor(ref, dtype=torch.float32), (0, ref_len - len(ref)))
        for ref in references
    ]
    references = torch.stack(references)  # (N, T)

    # 혼합 신호 길이 맞추기
    mixture = mixture[:, :ref_len]  # (1, T)

    # SI-SNR 계산
    si_snr_mixture = calculate_si_snr(mixture.repeat(len(references), 1), references).mean().item()
    si_snr_estimates = calculate_si_snr(estimates, references).mean().item()

    # SI-SNRi 및 SDRi 계산
    si_snri = si_snr_estimates - si_snr_mixture
    # SDR 계산 (Asteroid의 get_metrics 사용)
    metrics_mixture = get_metrics(
        references.numpy(),         # 정답 신호
        mixture.numpy(),            # 혼합 신호
        references.numpy(),         # 기준은 항상 정답 신호
        sample_rate=8000,
        metrics_list=["sdr"]
    )
    metrics_estimates = get_metrics(
        references.numpy(),         # 정답 신호
        estimates.numpy(),          # 추정 신호
        references.numpy(),         # 기준은 항상 정답 신호
        sample_rate=8000,
        metrics_list=["sdr"]
    )

    # SDRi 계산
    sdr_mixture = metrics_mixture["sdr"]
    sdr_estimates = metrics_estimates["sdr"]
    sdri = sdr_estimates - sdr_mixture
    return si_snri, sdri

# %%
# 메인 함수
def main(dataset_path):
    # 데이터 로드
    file_list = load_dataset(dataset_path)

    # 모델 초기화
    model = initialize_model()

    total_si_snri = 0
    total_sdri = 0
    total_files = len(file_list)

    print(f"총 {total_files}개의 파일을 처리합니다...")

    # 각 파일에 대해 처리
    for idx, (mixed_file, source_files) in enumerate(file_list):
        print(f"[{idx + 1}/{total_files}] Processing: {mixed_file}")

        # 혼합 오디오 및 소스 로드
        mixed_wave, _ = sf.read(mixed_file)
        target_waves = [sf.read(src)[0] for src in source_files]

        # 입력 데이터 준비
        mixture = torch.tensor(mixed_wave, dtype=torch.float32).unsqueeze(0)  # (1, T)
        references = [torch.tensor(tgt, dtype=torch.float32) for tgt in target_waves]


        # 음성 분리 수행
        with torch.no_grad():
            estimates = model(mixture)  # 모델 추정 결과 (B, T, N)

        # 디버깅: estimates 내용 확인
        print(f"Model output shape: {estimates.shape}")

        # SI-SNRi 및 SDRi 계산
        si_snri, sdri = calculate_metrics(estimates, references, mixture)
        total_si_snri += si_snri
        total_sdri += sdri

        print(f"  SI-SNRi: {si_snri:.2f} dB, SDRi: {sdri:.2f} dB")

    # 최종 결과 출력
    avg_si_snri = total_si_snri / total_files
    avg_sdri = total_sdri / total_files
    print(f"\n평균 SI-SNRi: {avg_si_snri:.2f} dB")
    print(f"평균 SDRi: {avg_sdri:.2f} dB")

# %%
DATASET_PATH = "/content/drive/MyDrive/Dataset/mk_1800_dataset/test"
main(DATASET_PATH)
# Out:
# 총 180개의 파일을 처리합니다...
# [1/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_401.wav
# Model output shape: torch.Size([1, 2, 55125])
# Adjusted estimates shape: torch.Size([2, 55125])
# <ipython-input-35-1d7d47f918f0>:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   else torch.nn.functional.pad(torch.tensor(ref, dtype=torch.float32), (0, ref_len - len(ref)))
#   SI-SNRi: -18.33 dB, SDRi: -9.87 dB
# [2/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_402.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -19.69 dB, SDRi: -12.18 dB
# [3/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_403.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -27.53 dB, SDRi: 7.63 dB
# [4/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_404.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -7.12 dB, SDRi: 7.97 dB
# [5/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_405.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -21.36 dB, SDRi: -20.82 dB
# [6/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_406.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.36 dB, SDRi: -20.95 dB
# [7/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_407.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -4.46 dB, SDRi: -12.56 dB
# [8/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_408.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.25 dB, SDRi: -14.78 dB
# [9/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_409.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 5.19 dB, SDRi: -10.64 dB
# [10/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_410.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.82 dB, SDRi: -9.13 dB
# [11/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_411.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 1.16 dB, SDRi: -7.77 dB
# [12/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_412.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -32.39 dB, SDRi: -34.58 dB
# [13/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_413.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -19.60 dB, SDRi: -16.05 dB
# [14/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_414.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.13 dB, SDRi: 4.70 dB
# [15/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_415.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -24.10 dB, SDRi: -30.40 dB
# [16/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_416.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.53 dB, SDRi: -7.31 dB
# [17/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_417.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -5.04 dB, SDRi: -16.39 dB
# [18/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_418.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -32.06 dB, SDRi: 6.57 dB
# [19/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_419.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 0.82 dB, SDRi: 8.33 dB
# [20/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_420.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -11.10 dB, SDRi: -14.09 dB
# [21/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_421.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.57 dB, SDRi: -12.88 dB
# [22/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_422.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -17.62 dB, SDRi: -12.83 dB
# [23/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_423.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.14 dB, SDRi: -22.95 dB
# [24/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_424.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 0.51 dB, SDRi: -15.05 dB
# [25/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_425.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -28.23 dB, SDRi: 9.39 dB
# [26/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_426.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -9.19 dB, SDRi: -6.12 dB
# [27/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_427.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -3.95 dB, SDRi: -26.55 dB
# [28/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_428.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -16.54 dB, SDRi: 2.20 dB
# [29/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_429.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -4.25 dB, SDRi: -12.49 dB
# [30/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_430.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -24.96 dB, SDRi: -0.43 dB
# [31/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_431.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 7.07 dB, SDRi: 11.59 dB
# [32/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_432.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.51 dB, SDRi: -5.21 dB
# [33/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_433.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -7.13 dB, SDRi: 6.10 dB
# [34/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_434.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -29.52 dB, SDRi: 1.31 dB
# [35/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_435.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -20.77 dB, SDRi: -3.95 dB
# [36/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_436.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -30.09 dB, SDRi: 5.57 dB
# [37/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_437.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.37 dB, SDRi: -11.99 dB
# [38/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_438.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -42.07 dB, SDRi: -39.45 dB
# [39/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_439.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -12.95 dB, SDRi: 3.77 dB
# [40/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_440.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.71 dB, SDRi: 0.14 dB
# [41/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_441.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.28 dB, SDRi: -23.39 dB
# [42/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_442.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -24.34 dB, SDRi: -9.13 dB
# [43/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_443.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -16.24 dB, SDRi: -10.53 dB
# [44/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_444.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -19.13 dB, SDRi: -7.02 dB
# [45/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_445.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -1.86 dB, SDRi: -5.79 dB
# [46/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_446.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -32.16 dB, SDRi: -17.40 dB
# [47/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_447.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -21.47 dB, SDRi: -9.02 dB
# [48/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_448.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 1.89 dB, SDRi: 3.26 dB
# [49/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_449.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.20 dB, SDRi: 15.47 dB
# [50/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_450.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -14.19 dB, SDRi: 4.13 dB
# [51/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_451.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -31.46 dB, SDRi: -42.67 dB
# [52/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_452.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -27.35 dB, SDRi: 10.51 dB
# [53/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_453.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -1.79 dB, SDRi: -11.30 dB
# [54/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_454.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -24.76 dB, SDRi: 3.26 dB
# [55/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_455.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -33.02 dB, SDRi: -30.85 dB
# [56/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_456.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -11.60 dB, SDRi: -0.73 dB
# [57/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_457.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -32.12 dB, SDRi: -15.33 dB
# [58/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_458.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -14.09 dB, SDRi: -9.94 dB
# [59/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_459.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -2.27 dB, SDRi: 11.93 dB
# [60/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Animal_460.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.21 dB, SDRi: 11.76 dB
# [61/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_401.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -9.14 dB, SDRi: -6.89 dB
# [62/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_402.wav
# Model output shape: torch.Size([1, 2, 240000])
# Adjusted estimates shape: torch.Size([2, 240000])
#   SI-SNRi: -19.99 dB, SDRi: 17.22 dB
# [63/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_403.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -28.09 dB, SDRi: 5.35 dB
# [64/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_404.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -21.94 dB, SDRi: -8.37 dB
# [65/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_405.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -14.86 dB, SDRi: -5.09 dB
# [66/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_406.wav
# Model output shape: torch.Size([1, 2, 110250])
# Adjusted estimates shape: torch.Size([2, 110250])
#   SI-SNRi: -4.03 dB, SDRi: -13.40 dB
# [67/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_407.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -13.69 dB, SDRi: -18.99 dB
# [68/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_408.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -10.67 dB, SDRi: -12.03 dB
# [69/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_409.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -5.55 dB, SDRi: -17.35 dB
# [70/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_410.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -17.93 dB, SDRi: -9.50 dB
# [71/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_411.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -14.55 dB, SDRi: -7.08 dB
# [72/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_412.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -4.37 dB, SDRi: -12.60 dB
# [73/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_413.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.94 dB, SDRi: 9.07 dB
# [74/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_414.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -13.55 dB, SDRi: -11.09 dB
# [75/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_415.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -2.66 dB, SDRi: -12.78 dB
# [76/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_416.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -8.64 dB, SDRi: -16.38 dB
# [77/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_417.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -12.89 dB, SDRi: 3.10 dB
# [78/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_418.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -1.00 dB, SDRi: -15.47 dB
# [79/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_419.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -13.22 dB, SDRi: -6.35 dB
# [80/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_420.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -22.19 dB, SDRi: -5.97 dB
# [81/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_421.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -13.17 dB, SDRi: -1.21 dB
# [82/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_422.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -19.30 dB, SDRi: -18.12 dB
# [83/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_423.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -10.65 dB, SDRi: -16.74 dB
# [84/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_424.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -24.96 dB, SDRi: -2.41 dB
# [85/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_425.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.83 dB, SDRi: -13.45 dB
# [86/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_426.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: 2.05 dB, SDRi: -19.66 dB
# [87/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_427.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -7.71 dB, SDRi: -17.72 dB
# [88/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_428.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -3.30 dB, SDRi: -10.01 dB
# [89/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_429.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -23.16 dB, SDRi: -10.83 dB
# [90/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_430.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -13.16 dB, SDRi: 4.94 dB
# [91/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_431.wav
# Model output shape: torch.Size([1, 2, 111285])
# Adjusted estimates shape: torch.Size([2, 111285])
#   SI-SNRi: 0.71 dB, SDRi: -17.52 dB
# [92/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_432.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -35.38 dB, SDRi: -22.26 dB
# [93/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_433.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -10.43 dB, SDRi: -11.31 dB
# [94/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_434.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -4.92 dB, SDRi: -5.68 dB
# [95/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_435.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -3.03 dB, SDRi: 8.70 dB
# [96/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_436.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.42 dB, SDRi: 8.49 dB
# [97/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_437.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -24.16 dB, SDRi: 3.51 dB
# [98/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_438.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -5.17 dB, SDRi: -7.33 dB
# [99/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_439.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.20 dB, SDRi: -13.83 dB
# [100/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_440.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -25.56 dB, SDRi: -13.48 dB
# [101/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_441.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.71 dB, SDRi: -2.88 dB
# [102/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_442.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -1.10 dB, SDRi: -17.15 dB
# [103/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_443.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -7.62 dB, SDRi: -8.19 dB
# [104/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_444.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -11.51 dB, SDRi: -14.74 dB
# [105/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_445.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -16.16 dB, SDRi: -15.05 dB
# [106/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_446.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.19 dB, SDRi: -2.10 dB
# [107/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_447.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -19.40 dB, SDRi: -20.31 dB
# [108/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_448.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -25.08 dB, SDRi: -13.04 dB
# [109/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_449.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -10.68 dB, SDRi: -6.78 dB
# [110/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_450.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -17.51 dB, SDRi: -10.39 dB
# [111/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_451.wav
# Model output shape: torch.Size([1, 2, 111275])
# Adjusted estimates shape: torch.Size([2, 111275])
#   SI-SNRi: -9.20 dB, SDRi: -20.10 dB
# [112/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_452.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -17.83 dB, SDRi: -17.39 dB
# [113/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_453.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -0.79 dB, SDRi: -16.93 dB
# [114/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_454.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -14.41 dB, SDRi: -2.11 dB
# [115/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_455.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -4.07 dB, SDRi: -18.18 dB
# [116/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_456.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -10.78 dB, SDRi: -7.44 dB
# [117/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_457.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -20.65 dB, SDRi: -8.59 dB
# [118/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_458.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -14.20 dB, SDRi: 1.43 dB
# [119/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_459.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -15.53 dB, SDRi: -17.99 dB
# [120/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Animal_Human_460.wav
# Model output shape: torch.Size([1, 2, 220500])
# Adjusted estimates shape: torch.Size([2, 220500])
#   SI-SNRi: -12.36 dB, SDRi: -2.91 dB
# [121/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_401.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.28 dB, SDRi: -6.69 dB
# [122/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_402.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.02 dB, SDRi: -3.30 dB
# [123/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_403.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.65 dB, SDRi: -4.59 dB
# [124/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_404.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.69 dB, SDRi: -4.22 dB
# [125/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_405.wav
# Model output shape: torch.Size([1, 2, 240000])
# Adjusted estimates shape: torch.Size([2, 240000])
#   SI-SNRi: -16.73 dB, SDRi: -12.04 dB
# [126/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_406.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.71 dB, SDRi: -2.91 dB
# [127/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_407.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.79 dB, SDRi: -3.83 dB
# [128/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_408.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.77 dB, SDRi: -5.23 dB
# [129/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_409.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -32.66 dB, SDRi: -6.21 dB
# [130/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_410.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.37 dB, SDRi: -5.79 dB
# [131/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_411.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.78 dB, SDRi: -4.19 dB
# [132/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_412.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.95 dB, SDRi: -3.75 dB
# [133/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_413.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.88 dB, SDRi: -5.94 dB
# [134/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_414.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.08 dB, SDRi: -3.60 dB
# [135/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_415.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.39 dB, SDRi: -4.24 dB
# [136/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_416.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.73 dB, SDRi: -3.70 dB
# [137/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_417.wav
# Model output shape: torch.Size([1, 2, 240000])
# Adjusted estimates shape: torch.Size([2, 240000])
#   SI-SNRi: -10.14 dB, SDRi: -14.52 dB
# [138/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_418.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -25.22 dB, SDRi: -7.05 dB
# [139/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_419.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.13 dB, SDRi: -4.92 dB
# [140/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_420.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.02 dB, SDRi: -5.80 dB
# [141/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_421.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.42 dB, SDRi: -3.33 dB
# [142/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_422.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.79 dB, SDRi: -3.38 dB
# [143/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_423.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.06 dB, SDRi: -3.64 dB
# [144/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_424.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.76 dB, SDRi: -3.68 dB
# [145/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_425.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.40 dB, SDRi: -4.91 dB
# [146/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_426.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.37 dB, SDRi: -4.39 dB
# [147/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_427.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.46 dB, SDRi: -4.24 dB
# [148/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_428.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.52 dB, SDRi: -5.01 dB
# [149/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_429.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.86 dB, SDRi: -5.07 dB
# [150/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_430.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.21 dB, SDRi: -3.86 dB
# [151/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_431.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.02 dB, SDRi: -3.05 dB
# [152/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_432.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.52 dB, SDRi: -5.86 dB
# [153/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_433.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.02 dB, SDRi: -5.14 dB
# [154/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_434.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.92 dB, SDRi: -5.16 dB
# [155/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_435.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.09 dB, SDRi: -6.21 dB
# [156/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_436.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.59 dB, SDRi: -5.50 dB
# [157/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_437.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -22.32 dB, SDRi: -5.77 dB
# [158/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_438.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.64 dB, SDRi: -5.95 dB
# [159/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_439.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.94 dB, SDRi: -3.88 dB
# [160/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_440.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.94 dB, SDRi: -6.47 dB
# [161/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_441.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.26 dB, SDRi: -6.76 dB
# [162/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_442.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.11 dB, SDRi: -3.45 dB
# [163/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_443.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.67 dB, SDRi: -7.44 dB
# [164/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_444.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.45 dB, SDRi: -5.75 dB
# [165/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_445.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.47 dB, SDRi: -3.86 dB
# [166/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_446.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.32 dB, SDRi: -4.50 dB
# [167/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_447.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.73 dB, SDRi: -5.26 dB
# [168/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_448.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.74 dB, SDRi: -4.34 dB
# [169/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_449.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.97 dB, SDRi: -4.20 dB
# [170/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_450.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -25.18 dB, SDRi: -7.72 dB
# [171/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_451.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.72 dB, SDRi: -4.70 dB
# [172/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_452.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.59 dB, SDRi: -3.53 dB
# [173/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_453.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -19.43 dB, SDRi: -5.04 dB
# [174/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_454.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -21.05 dB, SDRi: -5.72 dB
# [175/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_455.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.82 dB, SDRi: -4.52 dB
# [176/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_456.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -16.92 dB, SDRi: -4.84 dB
# [177/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_457.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.22 dB, SDRi: -4.85 dB
# [178/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_458.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -20.24 dB, SDRi: -4.60 dB
# [179/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_459.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -18.95 dB, SDRi: -5.20 dB
# [180/180] Processing: /content/drive/MyDrive/Dataset/mk_1800_dataset/test/mixed_data/Human_Human_460.wav
# Model output shape: torch.Size([1, 2, 80000])
# Adjusted estimates shape: torch.Size([2, 80000])
#   SI-SNRi: -24.29 dB, SDRi: -4.83 dB
#
# 평균 SI-SNRi: -17.10 dB
# 평균 SDRi: -7.30 dB

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

def calculate_model_metrics(model):
    """
    Args:
        model: PyTorch 모델

    Returns:
        params (str): 모델 파라미터 수
        macs (str): 모델 MACs 수
    """
    # 입력 데이터 크기 (예: 1초 길이의 신호, 8000 Hz 샘플링 레이트 가정)
    input_size = (1, 32000)  # (Batch, Time)

    # 모델 파라미터 수 계산
    print("모델 요약:")
    summary(model, input_size=input_size)

    # MACs 수 계산
    macs, params = get_model_complexity_info(
        model,
        input_size,
        as_strings=True,
        print_per_layer_stat=False,
        verbose=False
    )
    return params, macs

# DualPathRNN 또는 DPTNet 모델 초기화
from asteroid.models import DPRNNTasNet

# 모델 생성
model = DPRNNTasNet(n_src=2)

# 파라미터와 MACs 계산
params, macs = calculate_model_metrics(model)
print(f"모델 파라미터 수: {params}")
print(f"모델 MACs 수: {macs}")
# Out:
# 모델 요약:
# 모델 파라미터 수: 3.65 M
# 모델 MACs 수: 30.12 GMac
